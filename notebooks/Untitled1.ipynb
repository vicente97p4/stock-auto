# %%
import pandas as pd
corp_info = pd.read_csv('corp.csv', header=0, encoding='euc-kr')
corp_info = corp_info[['종목코드', '종목명', '종가', '상장주식수']]
corp_info['종목코드'].apply(lambda x: 'A'+str(x).zfill(6))
# for idx, c in enumerate(corp_info['종목코드']):
#     corp_info.loc[idx, '종목코드'] = 'A'+str(c).zfill(6)
corp_info
# Out:
#       종목코드         종목명       종가       상장주식수
# 0     5930        삼성전자    70600  5969782550
# 1      660      SK하이닉스   106000   728002365
# 2    35420       NAVER   411500   164263395
# 3    35720         카카오   130000   445361320
# 4   207940    삼성바이오로직스   865000    66165000
# 5    51910        LG화학   790000    70592343
# 6     5935       삼성전자우    66600   822886700
# 7     6400       삼성SDI   751000    68764530
# 8     5380         현대차   214000   213668187
# 9      270          기아    87000   405363347
# 10   68270        셀트리온   208500   137934716
# 11  323410       카카오뱅크    60000   475100237
# 12    5490       POSCO   297500    87186835
# 13   12330       현대모비스   252000    94793094
# 14  105560        KB금융    56000   415807920
# 15  259960        크래프톤   468000    48956545
# 16   17670       SK텔레콤   309500    72060143
# 17   96770     SK이노베이션   239500    92465564
# 18  377300       카카오페이   169000   130367125
# 19   28260        삼성물산   116500   186887081
# ...
